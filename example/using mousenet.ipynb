# %%
import os
import sys
sys.path.append('../cmouse')
import network
import mousenet

# %%
net = network.load_network_from_pickle('./network_(3,64,64).pkl')

# %%
net.draw_graph()
net.draw_grad_graph()

# %%
mousenet = mousenet.MouseNet(net)

# %%
import torch
x = torch.rand(10,3,64,64)

# %%
mousenet.get_img_feature(x, ['VISp4'])
# Out:
# tensor([[0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.6704, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.3711, 0.4112],
#         ...,
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.0000],
#         [0.0000, 0.0000, 0.0000,  ..., 0.8164, 0.1955, 0.0248],
#         [0.0000, 0.0000, 0.0000,  ..., 0.0000, 0.0000, 0.2397]],
#        grad_fn=<AsStridedBackward>)

# %%
OUTPUT_AREAS = ['VISp5', 'VISl5', 'VISrl5', 'VISli5', 'VISpl5', 'VISal5', 'VISpor5']

mousenet.get_img_feature(x, OUTPUT_AREAS)
# Out:
# tensor([[ 0.4178,  0.0176,  0.0000,  ...,  0.3046, -0.2247,  0.5847],
#         [ 0.0000,  0.0000,  0.0000,  ..., -0.3312,  0.5115,  0.4098],
#         [ 0.1762,  0.0000,  0.0000,  ...,  0.5718,  0.2706,  0.3505],
#         ...,
#         [ 0.4990,  0.0000,  0.0000,  ...,  0.1536,  0.1703,  0.2080],
#         [ 0.4577,  0.0000,  0.0000,  ...,  0.1367,  0.3434,  0.6204],
#         [ 0.0628,  0.5025,  0.0000,  ...,  0.0382,  0.5314,  0.4560]],
#        grad_fn=<CatBackward>)
